# %% [markdown]
# # Module to scrape and store data in local storage as CSV
#
# * Adaptation from: https://github.com/jorgeviz/depcdmx
#
# * Fields: name, description, location, link, price, operation, rooms, bathrooms, construction (m2), terrain (m2)
#
# * Data scraped between May 30 and June 1

# %% [markdown]
# ## 1. Dependencies

# %%
#  
import requests
import statistics
import pandas as pd
from bs4 import BeautifulSoup
import datetime as dt
import os
from pprint import pprint as pp

# %% [markdown]
# ## 2. Import, append, drop duplicates, etc. from csv tables

# %% [markdown]
# ### Import data

# %%
# CDMX operation = venta, departamentos
df_CDMX_Venta_D = pd.read_csv('data/RawData/inmuebles24-distrito-federal-venta-departamentos.csv', 
                              encoding = 'utf-8-sig')
df_CDMX_Venta_D['propiedad'] = 'Departamento'
df_CDMX_Venta_D['entidad'] = 'CDMX'
df_CDMX_Venta_D.head(3)
# Out:
#                                         name  \
# 0         Sierra Gorda, Lomas de Chapultepec
# 1  Enquentro Residencial Insurgentes Mixcoac
# 2                       Sky Tower Lindavista
#
#                                             location  \
# 0  Calle Sierra gorda, Lomas de Chapultepec, Migu...
# 1  Patriotismo 883, Insurgentes Mixcoac, Benito J...
# 2  Av. Insurgentes Norte. 1346, Lindavista,  Ciud...
#
#                                          description  \
# 0  La exclusiva zona residencial de Lomas de Chap...
# 1  Enquentro un proyecto moderno y singular. Ven ...
# 2  Sky tower lindavista es un desarrollo de 184 d...
#
#                                                 link          price operation  \
# 0  /propiedades/sierra-gorda-lomas-de-chapultepec...  MN 25,000,000     venta
# 1  /propiedades/enquentro-residencial-insurgentes...   MN 5,523,587     venta
# 2    /propiedades/sky-tower-lindavista-54456938.html   MN 3,210,000     venta
#
#    rooms  bathrooms  construction (m2)  terrain (m2)     propiedad entidad
# 0    2.5        NaN              282.0         416.5  Departamento    CDMX
# 1    2.5        NaN              140.5         140.5  Departamento    CDMX
# 2    2.0        NaN               79.5         122.0  Departamento    CDMX

# %%
# CDMX operation = venta, casas
df_CDMX_Venta_C = pd.read_csv('data/RawData/inmuebles24-distrito-federal-venta-casas.csv', 
                              encoding = 'utf-8-sig')
df_CDMX_Venta_C['propiedad'] = 'Casa'
df_CDMX_Venta_C['entidad'] = 'CDMX'
df_CDMX_Venta_C.head(3)
# Out:
#                                                 name  \
# 0                                         Torreón 10
# 1                      Casa - Jardines en La Montaña
# 2  Bosques de Reforma, Casa Sola a La Venta en Bo...
#
#                                             location  \
# 0       Calle Torreón 10, Roma Sur, Roma, Cuauhtémoc
# 1  Jardines EN LA Montaña, Residencia Frente AL B...
# 2  Bosques de Reforma, Casa Sola a la Venta en Bo...
#
#                                          description  \
# 0  ¡Casas en venta! De 158m2 a 175m2 con 3 recáma...
# 1  Espectacular casa en venta con hermosas vistas...
# 2  Bosques de las Lomas, Bosque de la Reforma, ca...
#
#                                                 link          price operation  \
# 0              /propiedades/torreon-10-54395385.html   MN 8,230,000     venta
# 1  /propiedades/casa-jardines-en-la-montana-56828...  MN 35,500,000     venta
# 2  /propiedades/bosques-de-reforma-casa-sola-a-la...  MN 34,500,000     venta
#
#    rooms  bathrooms  construction (m2)  terrain (m2) propiedad entidad
# 0    3.0        NaN              166.5          58.0      Casa    CDMX
# 1    3.0        3.0              790.0         635.0      Casa    CDMX
# 2    3.0        3.0              736.0         715.0      Casa    CDMX

# %%
# CDMX operation = venta, casas en condominio
df_CDMX_Venta_CC = pd.read_csv('data/RawData/inmuebles24-distrito-federal-venta-casa-en-condominio.csv', 
                               encoding = 'utf-8-sig')
df_CDMX_Venta_CC['propiedad'] = 'Casa en Condominio'
df_CDMX_Venta_CC['entidad'] = 'CDMX'
df_CDMX_Venta_CC.head(3)
# Out:
#                               name  \
# 0           Residencial Hidalgo 39
# 1                       Acacias 63
# 2  Pedregal - Residencias Privadas
#
#                                             location  \
# 0          San Francisco CulhuacAn Barrio , Coyoacán
# 1  florida, del valle sur, san jose insurgentes, ...
# 2  ESTEPA , Jardines del Pedregal de San Angel, C...
#
#                                          description  \
# 0  Desarrollo de 38 casas con planta baja y dos n...
# 1  Hermosas residencias de 3 niveles a estrenar u...
# 2  Condominio horizontal nuevo. 13 residencias pr...
#
#                                                 link          price operation  \
# 0  /propiedades/residencial-hidalgo-39-51632248.html   MN 4,600,000     venta
# 1              /propiedades/acacias-63-58312116.html  MN 12,822,000     venta
# 2  /propiedades/pedregal-residencias-privadas-574...  MN 30,914,900     venta
#
#    rooms  bathrooms  construction (m2)  terrain (m2)           propiedad  \
# 0    3.0        NaN              185.5        3977.0  Casa en Condominio
# 1    3.0        NaN              245.0         360.0  Casa en Condominio
# 2    3.5        NaN              790.5         322.5  Casa en Condominio
#
#   entidad
# 0    CDMX
# 1    CDMX
# 2    CDMX

# %%
# CDMX operation = renta, departamentos
df_CDMX_Renta_D = pd.read_csv('data/RawData/inmuebles24-distrito-federal-renta-departamentos.csv', 
                              encoding = 'utf-8-sig')
df_CDMX_Renta_D['propiedad'] = 'Departamento'
df_CDMX_Renta_D['entidad'] = 'CDMX'
df_CDMX_Renta_D.head(3)
# Out:
#                                      name  \
# 0             City Rent - Parques Polanco
# 1  Nomad Santa Fe, Departamentos en Renta
# 2   Nomad Mítikah, Departamentos en Renta
#
#                                        location  \
# 0         Lago Mayor 6, Polanco, Miguel Hidalgo
# 1    Av. Santa Fe 578, Santa Fe, Alvaro Obregón
# 2  Av. Río Churubusco 601, Del Carmen, Coyoacán
#
#                                          description  \
# 0  "All Inclusive Lifestyle" En City Rent creamos...
# 1  Renta tu próximo depa desde la comodidad de tu...
# 2  Renta tu próximo depa desde la comodidad de tu...
#
#                                                 link      price operation  \
# 0  /propiedades/city-rent-parques-polanco-5355970...  MN 14,900     renta
# 1  /propiedades/nomad-santa-fe-departamentos-en-r...  MN 16,500     renta
# 2  /propiedades/nomad-mitikah-departamentos-en-re...  MN 14,800     renta
#
#    rooms  bathrooms  construction (m2)  terrain (m2)     propiedad entidad
# 0    2.0        NaN               92.0          98.0  Departamento    CDMX
# 1    1.5        NaN                NaN           NaN  Departamento    CDMX
# 2    1.5        NaN                NaN           NaN  Departamento    CDMX

# %%
# CDMX operation = renta, casas
df_CDMX_Renta_C = pd.read_csv('data/RawData/inmuebles24-distrito-federal-renta-casas.csv', 
                              encoding = 'utf-8-sig')
df_CDMX_Renta_C['propiedad'] = 'Casa'
df_CDMX_Renta_C['entidad'] = 'CDMX'
df_CDMX_Renta_C.head(3)
# Out:
#                                                 name  \
# 0           Monte Pichincha, Magnifica Casa en Renta
# 1  Casa en Renta Rincón de Las Lomas, Bosque del Sur
# 2     Casa en Renta Plaza Mayorazgo de Luyando, Xoco
#
#                                             location  \
# 0  Monte Pichincha 21, Lomas de Reforma, Miguel H...
# 1  Rincón de las Lomas, Bosque Residencial del Su...
# 2    Plaza Mayorazgo de Luyando, Xoco, Benito Juárez
#
#                                          description  \
# 0  Magnifica casa en renta, ubicada en una de las...
# 1  En Homie no te pedimos aval, te respaldamos y ...
# 2  En Homie no te pedimos aval, te respaldamos y ...
#
#                                                 link       price operation  \
# 0  /propiedades/monte-pichincha-magnifica-casa-en...  MN 165,000     renta
# 1  /propiedades/casa-en-renta-rincon-de-las-lomas...   MN 25,300     renta
# 2  /propiedades/casa-en-renta-plaza-mayorazgo-de-...   MN 31,000     renta
#
#    rooms  bathrooms  construction (m2)  terrain (m2) propiedad entidad
# 0    4.0        4.0              560.0         500.0      Casa    CDMX
# 1    3.0        1.0              400.0         400.0      Casa    CDMX
# 2    3.0        3.0              232.0         232.0      Casa    CDMX

# %%
# CDMX operation = renta, casas en condominio
df_CDMX_Renta_CC = pd.read_csv('data/RawData/inmuebles24-distrito-federal-renta-casa-en-condominio.csv', 
                               encoding = 'utf-8-sig')
df_CDMX_Renta_CC['propiedad'] = 'Casa en Condominio'
df_CDMX_Renta_CC['entidad'] = 'CDMX'
df_CDMX_Renta_CC.head(3)
# Out:
#                                                 name  \
# 0  Aaa! Oportunidad! Renta Casa en Conjunto, Bosq...
# 1         Excelente Casa en Condominio Para Estrenar
# 2  Vendo/rento Hermosa Casa en Condominio Horizon...
#
#                                          location  \
# 0     Bosques de las Lomas, Cuajimalpa de Morelos
# 1           San Pedro de los Pinos, Benito Juárez
# 2  COAHUILA 83, Cuajimalpa, Cuajimalpa de Morelos
#
#                                          description  \
# 0  Disponible en diciembre 2019! Oportunidad! Ren...
# 1  Excelente casa en condominio En San Pedro Los ...
# 2  Hermosa casa en perfecto estado de conservació...
#
#                                                 link       price operation  \
# 0  /propiedades/aaa!-oportunidad!-renta-casa-en-c...  MN 100,000     renta
# 1  /propiedades/excelente-casa-en-condominio-para...   MN 28,500     renta
# 2  /propiedades/vendo-rento-hermosa-casa-en-condo...   MN 22,000     renta
#
#    rooms  bathrooms  construction (m2)  terrain (m2)           propiedad  \
# 0      4        4.0              550.0         550.0  Casa en Condominio
# 1      3        2.0              214.0          64.0  Casa en Condominio
# 2      3        2.0              220.0         240.0  Casa en Condominio
#
#   entidad
# 0    CDMX
# 1    CDMX
# 2    CDMX

# %%
# EDOMEX operation = venta, departamentos
df_EDOMEX_Venta_D = pd.read_csv('data/RawData/inmuebles24-edo.-de-mexico-venta-departamentos.csv', 
                                encoding = 'utf-8-sig')
df_EDOMEX_Venta_D['propiedad'] = 'Departamento'
df_EDOMEX_Venta_D['entidad'] = 'EDOMEX'
df_EDOMEX_Venta_D.head(3)
# Out:
#                                                 name  \
# 0  Desarrollo Bosques de La Herradura Los Ríos Re...
# 1                     Binôme Townhouses & Apartments
# 2                             Nova Lifestyle Bosques
#
#                                             location  \
# 0  Bosque de Minas, Bosques de la Herradura, Huix...
# 1  Av. Vista Real, Green House, Lomas Country Clu...
# 2  Antiguo Camino a Tecamachalco 29, Lomas del Ol...
#
#                                          description  \
# 0  Los Ríos Residencial es un proyecto con 60 exc...
# 1  BinÔme nace como respuesta a la necesidad de v...
# 2  Propone una nueva forma de vivir, donde arquit...
#
#                                                 link         price operation  \
# 0  /propiedades/desarrollo-bosques-de-la-herradur...  MN 4,850,000     venta
# 1  /propiedades/binome-townhouses-apartments-5530...  MN 8,995,000     venta
# 2  /propiedades/nova-lifestyle-bosques-56703094.html  MN 6,539,784     venta
#
#    rooms  bathrooms  construction (m2)  terrain (m2)     propiedad entidad
# 0    2.0        NaN              119.0         175.5  Departamento  EDOMEX
# 1    3.0        NaN              283.0           NaN  Departamento  EDOMEX
# 2    3.0        NaN              245.0           NaN  Departamento  EDOMEX

# %%
# EDOMEX operation = venta, casas
df_EDOMEX_Venta_C = pd.read_csv('data/RawData/inmuebles24-edo.-de-mexico-venta-casas.csv', 
                                encoding = 'utf-8-sig')
df_EDOMEX_Venta_C['propiedad'] = 'Casa'
df_EDOMEX_Venta_C['entidad'] = 'EDOMEX'
df_EDOMEX_Venta_C.head(3)
# Out:
#                                                 name  \
# 0  Casas Cuautitlán Izcalli - Atlanta Edo. de México
# 1                                             Ribera
# 2                                            Colina1
#
#                                             location  \
# 0                        Atlanta, Cuautitlán Izcalli
# 1  Av. Jorge Jiménez Cantú, Bosque Esmeralda,  Cd...
# 2  v. Jorge Jiménez Cantú, Bosque Esmeralda, 5293...
#
#                                          description  \
# 0  Visita nuestra casa muestra. Acabados: -Muros:...
# 1  Invierte en una casa diseñada especialmente pa...
# 2  Invierte en una casa diseñada especialmente pa...
#
#                                                 link         price operation  \
# 0  /propiedades/casas-cuautitlan-izcalli-atlanta-...  MN 2,689,325     venta
# 1                  /propiedades/ribera-58320942.html  MN 3,500,000     venta
# 2                 /propiedades/colina1-58411650.html  MN 3,240,000     venta
#
#    rooms  bathrooms  construction (m2)  terrain (m2) propiedad entidad
# 0    3.0        NaN               96.0         105.0      Casa  EDOMEX
# 1    3.0        NaN              134.0          90.0      Casa  EDOMEX
# 2    3.0        NaN              110.0           NaN      Casa  EDOMEX

# %%
# EDOMEX operation = venta, casas en condominio
df_EDOMEX_Venta_CC = pd.read_csv('data/RawData/inmuebles24-edo.-de-mexico-venta-casa-en-condominio.csv', 
                                 encoding = 'utf-8-sig')
df_EDOMEX_Venta_CC['propiedad'] = 'Casa en Condominio'
df_EDOMEX_Venta_CC['entidad'] = 'EDOMEX'
df_EDOMEX_Venta_CC.head(3)
# Out:
#                                                 name  \
# 0   Encinos Residencial (Oficial) en Rancho San Juan
# 1  Rinconada de La Estadía Siente La Libertad de ...
# 2  "Oyamel" en Circuito Avándaro (9 Exclusivas Ca...
#
#                                             location  \
# 0  Av. Dr. Jimenez Cantú s/n, Rancho San Juan, Ra...
# 1  la estadia , Bosque Esmeralda, Atizapán de Zar...
# 2  Cerrada Vega de las Flores, Avandaro, AvAndaro...
#
#                                          description  \
# 0  Residencial encinos (Oficial) dentro de rancho...
# 1  La Estadía es el lugar ideal para tu familia. ...
# 2  Conjunto de 9 lujosas casas de descanso, que p...
#
#                                                 link          price operation  \
# 0  /propiedades/encinos-residencial-oficial-en-ra...  MN 10,437,013     venta
# 1  /propiedades/rinconada-de-la-estadia-siente-la...  MN 15,290,000     venta
# 2  /propiedades/-oyamel-en-circuito-avandaro-9-ex...  MN 14,950,000     venta
#
#    rooms  bathrooms  construction (m2)  terrain (m2)           propiedad  \
# 0      4        NaN              323.0           NaN  Casa en Condominio
# 1      3        NaN              448.0         549.5  Casa en Condominio
# 2      4        NaN              447.0       11000.0  Casa en Condominio
#
#   entidad
# 0  EDOMEX
# 1  EDOMEX
# 2  EDOMEX

# %%
# EDOMEX operation = renta, departamentos
df_EDOMEX_Renta_D = pd.read_csv('data/RawData/inmuebles24-edo.-de-mexico-renta-departamentos.csv', 
                                encoding = 'utf-8-sig')
df_EDOMEX_Renta_D['propiedad'] = 'Departamento'
df_EDOMEX_Renta_D['entidad'] = 'EDOMEX'
df_EDOMEX_Renta_D.head(3)
# Out:
#                                                 name  \
# 0  Renta de Departamento Premium Nuevo en Bosque ...
# 1  Frondoso II, Depa Terraza Piso Alto, Venta o r...
# 2     Departamento en Renta Isaac Newton, Las Torres
#
#                                             location  \
# 0                 SìRENTA, Bosque Real, Huixquilucan
# 1  Frondoso II Departamento con Terraza en Piso A...
# 2                   Isaac Newton, Las Torres, Toluca
#
#                                          description  \
# 0  ¡Aprovecha nuestra promoción covid-19: Grandes...
# 1  Lomas Country Club, Frondoso ii, departamento ...
# 2  En Homie no te pedimos aval, te respaldamos y ...
#
#                                                 link      price operation  \
# 0  /propiedades/renta-de-departamento-premium-nue...  MN 21,700     renta
# 1  /propiedades/frondoso-ii-depa-terraza-piso-alt...  MN 42,000     renta
# 2  /propiedades/departamento-en-renta-isaac-newto...   MN 4,500     renta
#
#    rooms  bathrooms  construction (m2)  terrain (m2)     propiedad entidad
# 0    2.5        NaN              180.5         180.5  Departamento  EDOMEX
# 1    3.0        3.0              385.0         385.0  Departamento  EDOMEX
# 2    2.0        1.0               50.0          50.0  Departamento  EDOMEX

# %%
# EDOMEX operation = renta, casas
df_EDOMEX_Renta_C = pd.read_csv('data/RawData/inmuebles24-edo.-de-mexico-renta-casas.csv', 
                                encoding = 'utf-8-sig')
df_EDOMEX_Renta_C['propiedad'] = 'Casa'
df_EDOMEX_Renta_C['entidad'] = 'EDOMEX'
df_EDOMEX_Renta_C.head(3)
# Out:
#                                                 name  \
# 0          Casa en Renta Jardines Botanicos, Tecamac
# 1         Casa en Renta Antioquia, San Pablo Tecalco
# 2  Casa en Renta Cerrada de Olivo Villas del Bosq...
#
#                                             location  \
# 0    Jardines Botanicos, Los Héroes Tecámac, Tecámac
# 1              Antioquia, San Pablo Tecalco, Tecámac
# 2  Cerrada de Olivo  Villas del bosque, San Anton...
#
#                                          description  \
# 0  En Homie no te pedimos aval, te respaldamos y ...
# 1  En Homie no te pedimos aval, te respaldamos y ...
# 2  En Homie no te pedimos aval, te respaldamos y ...
#
#                                                 link     price operation  \
# 0  /propiedades/casa-en-renta-jardines-botanicos-...  MN 4,500     renta
# 1  /propiedades/casa-en-renta-antioquia-san-pablo...  MN 4,500     renta
# 2  /propiedades/casa-en-renta-cerrada-de-olivo-vi...  MN 4,500     renta
#
#    rooms  bathrooms  construction (m2)  terrain (m2) propiedad entidad
# 0      2        1.0               72.0          72.0      Casa  EDOMEX
# 1      2        1.0               70.0          70.0      Casa  EDOMEX
# 2      3        2.0               90.0          90.0      Casa  EDOMEX

# %%
# EDOMEX operation = renta, casas en condominios
df_EDOMEX_Renta_CC = pd.read_csv('data/RawData/inmuebles24-edo.-de-mexico-renta-casa-en-condominio.csv', 
                                 encoding = 'utf-8-sig')
df_EDOMEX_Renta_CC['propiedad'] = 'Casa en Condominio'
df_EDOMEX_Renta_CC['entidad'] = 'EDOMEX'
df_EDOMEX_Renta_CC.head(3)
# Out:
#                                                 name  \
# 0  Preciosa Casa en Renta en Condominio Privado e...
# 1                     Casa en Renta, Punta Esmeralda
# 2  Bosque Esmeralda, Iluminada Casa en Condominio...
#
#                                             location  \
# 0                 Las Colonias, Atizapán de Zaragoza
# 1             Bosque Esmeralda, Atizapán de Zaragoza
# 2  CONDOMINIO MAGENTA ZONA ESMERALDA, Bosque Esme...
#
#                                          description  \
# 0  Preciosa casa en renta en condominio privado e...
# 1  120 metros de construcción muy bien aprovechad...
# 2  Como nueva, muy iluminada, linda vista, 3 reca...
#
#                                                 link      price operation  \
# 0  /propiedades/preciosa-casa-en-renta-en-condomi...  MN 25,000     renta
# 1  /propiedades/casa-en-renta-punta-esmeralda-520...  MN 17,500     renta
# 2  /propiedades/bosque-esmeralda-iluminada-casa-e...  MN 25,000     renta
#
#    rooms  bathrooms  construction (m2)  terrain (m2)           propiedad  \
# 0    3.0        3.0              190.0         220.0  Casa en Condominio
# 1    3.0        2.0              120.0         120.0  Casa en Condominio
# 2    3.0        2.0              150.0         275.0  Casa en Condominio
#
#   entidad
# 0  EDOMEX
# 1  EDOMEX
# 2  EDOMEX

# %% [markdown]
# ### Append dataframes

# %%
# Append CDMX - EDOMEX, operation = Venta
df_Venta = df_CDMX_Venta_D.append(df_CDMX_Venta_C)
df_Venta = df_Venta.append(df_CDMX_Venta_CC)
df_Venta = df_Venta.append(df_EDOMEX_Venta_D)
df_Venta = df_Venta.append(df_EDOMEX_Venta_C)
df_Venta = df_Venta.append(df_EDOMEX_Venta_CC)

df_Venta.head(3)
# Out:
#                                         name  \
# 0         Sierra Gorda, Lomas de Chapultepec
# 1  Enquentro Residencial Insurgentes Mixcoac
# 2                       Sky Tower Lindavista
#
#                                             location  \
# 0  Calle Sierra gorda, Lomas de Chapultepec, Migu...
# 1  Patriotismo 883, Insurgentes Mixcoac, Benito J...
# 2  Av. Insurgentes Norte. 1346, Lindavista,  Ciud...
#
#                                          description  \
# 0  La exclusiva zona residencial de Lomas de Chap...
# 1  Enquentro un proyecto moderno y singular. Ven ...
# 2  Sky tower lindavista es un desarrollo de 184 d...
#
#                                                 link          price operation  \
# 0  /propiedades/sierra-gorda-lomas-de-chapultepec...  MN 25,000,000     venta
# 1  /propiedades/enquentro-residencial-insurgentes...   MN 5,523,587     venta
# 2    /propiedades/sky-tower-lindavista-54456938.html   MN 3,210,000     venta
#
#    rooms  bathrooms  construction (m2)  terrain (m2)     propiedad entidad
# 0    2.5        NaN              282.0         416.5  Departamento    CDMX
# 1    2.5        NaN              140.5         140.5  Departamento    CDMX
# 2    2.0        NaN               79.5         122.0  Departamento    CDMX

# %%
#
pd.crosstab(df_Venta.propiedad, df_Venta.entidad, dropna = False)
# Out:
# entidad              CDMX  EDOMEX
# propiedad
# Casa                15929    7879
# Casa en Condominio   5242    7518
# Departamento        25520    8900

# %%
#
df_Venta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70988 entries, 0 to 7517
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               70988 non-null  object
#  1   location           70988 non-null  object
#  2   description        70834 non-null  object
#  3   link               70988 non-null  object
#  4   price              70988 non-null  object
#  5   operation          70988 non-null  object
#  6   rooms              70900 non-null  float64
#  7   bathrooms          68542 non-null  float64
#  8   construction (m2)  67453 non-null  float64
#  9   terrain (m2)       69223 non-null  float64
#  10  propiedad          70988 non-null  object
#  11  entidad            70988 non-null  object
# dtypes: float64(4), object(8)
# memory usage: 7.0+ MB

# %%
# Append CDMX - EDOMEX, operation = Renta
df_Renta = df_CDMX_Renta_D.append(df_CDMX_Renta_C)
df_Renta = df_Renta.append(df_CDMX_Renta_CC)
df_Renta = df_Renta.append(df_EDOMEX_Renta_D)
df_Renta = df_Renta.append(df_EDOMEX_Renta_C)
df_Renta = df_Renta.append(df_EDOMEX_Renta_CC)

df_Renta.head(3)
# Out:
#                                      name  \
# 0             City Rent - Parques Polanco
# 1  Nomad Santa Fe, Departamentos en Renta
# 2   Nomad Mítikah, Departamentos en Renta
#
#                                        location  \
# 0         Lago Mayor 6, Polanco, Miguel Hidalgo
# 1    Av. Santa Fe 578, Santa Fe, Alvaro Obregón
# 2  Av. Río Churubusco 601, Del Carmen, Coyoacán
#
#                                          description  \
# 0  "All Inclusive Lifestyle" En City Rent creamos...
# 1  Renta tu próximo depa desde la comodidad de tu...
# 2  Renta tu próximo depa desde la comodidad de tu...
#
#                                                 link      price operation  \
# 0  /propiedades/city-rent-parques-polanco-5355970...  MN 14,900     renta
# 1  /propiedades/nomad-santa-fe-departamentos-en-r...  MN 16,500     renta
# 2  /propiedades/nomad-mitikah-departamentos-en-re...  MN 14,800     renta
#
#    rooms  bathrooms  construction (m2)  terrain (m2)     propiedad entidad
# 0    2.0        NaN               92.0          98.0  Departamento    CDMX
# 1    1.5        NaN                NaN           NaN  Departamento    CDMX
# 2    1.5        NaN                NaN           NaN  Departamento    CDMX

# %%
#
pd.crosstab(df_Renta.propiedad, df_Renta.entidad, dropna = False)
# Out:
# entidad              CDMX  EDOMEX
# propiedad
# Casa                10032   30692
# Casa en Condominio   4022    6468
# Departamento        26145    6801

# %%
#
df_Renta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84160 entries, 0 to 6467
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               84160 non-null  object
#  1   location           84160 non-null  object
#  2   description        84157 non-null  object
#  3   link               84160 non-null  object
#  4   price              84160 non-null  object
#  5   operation          84160 non-null  object
#  6   rooms              84144 non-null  float64
#  7   bathrooms          83152 non-null  float64
#  8   construction (m2)  74804 non-null  float64
#  9   terrain (m2)       76772 non-null  float64
#  10  propiedad          84160 non-null  object
#  11  entidad            84160 non-null  object
# dtypes: float64(4), object(8)
# memory usage: 8.3+ MB

# %% [markdown]
# ### Drop duplicates

# %%
# Duplicates, operation = Venta
df_Venta_Unique = df_Venta.drop_duplicates()

pd.crosstab(df_Venta_Unique.propiedad, df_Venta_Unique.entidad, dropna = False)
# Out:
# entidad              CDMX  EDOMEX
# propiedad
# Casa                11670    6862
# Casa en Condominio   3175    3547
# Departamento        18976    6907

# %%
df_Venta_Unique.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51137 entries, 0 to 3896
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               51137 non-null  object
#  1   location           51137 non-null  object
#  2   description        51135 non-null  object
#  3   link               51137 non-null  object
#  4   price              51137 non-null  object
#  5   operation          51137 non-null  object
#  6   rooms              51055 non-null  float64
#  7   bathrooms          50493 non-null  float64
#  8   construction (m2)  48820 non-null  float64
#  9   terrain (m2)       50169 non-null  float64
#  10  propiedad          51137 non-null  object
#  11  entidad            51137 non-null  object
# dtypes: float64(4), object(8)
# memory usage: 5.1+ MB

# %%
# Duplicates, operation = Renta
df_Renta_Unique = df_Renta.drop_duplicates()

pd.crosstab(df_Renta_Unique.propiedad, df_Renta_Unique.entidad, dropna = False)
# Out:
# entidad              CDMX  EDOMEX
# propiedad
# Casa                 1637    2528
# Casa en Condominio    774     704
# Departamento        17757    4491

# %%
df_Renta_Unique.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27891 entries, 0 to 703
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               27891 non-null  object
#  1   location           27891 non-null  object
#  2   description        27888 non-null  object
#  3   link               27891 non-null  object
#  4   price              27891 non-null  object
#  5   operation          27891 non-null  object
#  6   rooms              27877 non-null  float64
#  7   bathrooms          27750 non-null  float64
#  8   construction (m2)  26543 non-null  float64
#  9   terrain (m2)       27429 non-null  float64
#  10  propiedad          27891 non-null  object
#  11  entidad            27891 non-null  object
# dtypes: float64(4), object(8)
# memory usage: 2.8+ MB

# %% [markdown]
# ### Save tables

# %%
# Save CDMX - EDOMEX, operation = Venta
df_Venta_Unique.to_csv('data/CleanData/inmuebles24-edo_Venta.csv', sep =',', encoding = 'utf-8-sig', index = False)

# %%
# Save CDMX - EDOMEX, operation = Renta
df_Renta_Unique.to_csv('data/CleanData/inmuebles24-edo_Renta.csv', sep =',', encoding = 'utf-8-sig', index = False)
